# %% [markdown]
# Run the following cell, wait for it to finish. It will then restart the runtime. Then you can run the rest of the notebook (don't run this cell again after the first time)

# %%
# !pip install -Ivq "tensorflow-gpu>=1.15,<2.0"
os.kill(os.getpid(), 9)
# Out:
# ...
#      |████████████████████████████████| 411.5MB 37kB/s
# ...
#      |████████████████████████████████| 4.1MB 41.0MB/s
# ...
#      |████████████████████████████████| 17.0MB 164kB/s
# ...
#      |████████████████████████████████| 3.8MB 41.4MB/s
# ...
#      |████████████████████████████████| 1.0MB 41.5MB/s
# ...
#      |████████████████████████████████| 51kB 9.6MB/s
# ...
#      |████████████████████████████████| 512kB 43.9MB/s
# ...
#      |████████████████████████████████| 296kB 47.6MB/s
# ...
#      |████████████████████████████████| 122kB 58.2MB/s
# ...
#      |████████████████████████████████| 61kB 10.1MB/s
# ...
#      |████████████████████████████████| 61kB 10.3MB/s
# ...
#      |████████████████████████████████| 583kB 46.3MB/s
# ...
#      |████████████████████████████████| 307kB 30.7MB/s
# ...
#      |████████████████████████████████| 92kB 11.1MB/s
# ...
#      |████████████████████████████████| 2.8MB 43.5MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp27-none-any.whl size=7539 sha256=4dc07a6dd0623cd0ea8291259a0798ec68b31ce629d9c2f67031c59ace198c5d
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
import shutil
# %cd ..
# %rm -r QRec-master
print(os.getcwd())
print("found data file" if os.path.exists("drive/Shareddrives/Shachar_Jonathan_RS/project/QRec-master.zip") else "data file not found")
if not os.path.exists("QRec-master"):
    zip_path = 'drive/Shareddrives/Shachar_Jonathan_RS/project/QRec-master.zip'
    print("importing data from drive")
    # !cp "{zip_path}" .
    # !unzip -q QRec-master.zip
    # !rm QRec-master.zip
# Out:
# Mounted at /content/drive
# rm: cannot remove 'QRec-master': No such file or directory
# /content
# found data file
# importing data from drive

# %%
# %cd drive/Shareddrives/Shachar_Jonathan_RS/project/code
# %cd QRec-master
print(os.listdir('.'))
# os.getcwd()
# Out:
# /content/QRec-master
# ['visual', 'drive', 'algorithm', 'results', 'config', 'tool', 'main', 'LICENSE', 'README.md', '.gitignore', 'structure', 'data', 'dataset', 'evaluation', 'baseclass']

# %%
import sys
# sys.path.extend(['/content/QRec-master/tool/'])
# !export PYTHONPATH="${PYTHONPATH}:/content/QRec-master/"
sys.path
# Out:
# ['',
#  '/env/python',
#  '/usr/lib/python2.7',
#  '/usr/lib/python2.7/plat-x86_64-linux-gnu',
#  '/usr/lib/python2.7/lib-tk',
#  '/usr/lib/python2.7/lib-old',
#  '/usr/lib/python2.7/lib-dynload',
#  '/usr/local/lib/python2.7/dist-packages',
#  '/usr/lib/python2.7/dist-packages',
#  '/usr/local/lib/python2.7/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
# %cd results
# for f in os.listdir('.'):
#   path = f
#   print(path)
#   if os.path.isfile(path):
#     shutil.copytree(path, os.path.join(r'drive/Shareddrives/Shachar_Jonathan_RS/project/results'))
# %cd ..

# %%
# !python2.7 main/main.py
import tensorflow as tf
tf.compat.v1.disable_v2_behavior()
# !python2.7 -m main/main
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0702 09:08:14.180130 139975972165504 deprecation.py:323] From /usr/local/lib/python2.7/dist-packages/tensorflow_core/python/compat/v2_compat.py:88: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# /usr/bin/python2.7: No module named main/main

# %%
# %rm results/*
# %cd ..
print(os.listdir('.'))
# !zip -qr QRec-master.zip QRec-master
shutil.copy('QRec-master.zip', 'drive/Shareddrives/Shachar_Jonathan_RS/project/QRec-master.zip')
from google.colab import files
# files.download("QRec-master.zip") 
# %cd QRec-master
# Out:
# /content
# ['.config', 'QRec-master.zip', 'drive', 'QRec-master', 'sample_data']
# /content/QRec-master

# %%
###########
# Out:
# [Errno 2] No such file or directory: 'QRec-master'
# /content/QRec-master
